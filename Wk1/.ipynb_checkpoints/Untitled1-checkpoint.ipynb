# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def plotseries(time,series,formatIcon='-',start=0,end=None,label=None):
    plt.figure(figsize=(10,6))
    plt.plot(time[start:end],series[start:end],formatIcon,label=label)
    plt.xlabel("Time")
    plt.ylabel("Series")
    plt.grid(True)
    if label:
        plt.legend(fontsize=14)

# %%
def trend(time,slope=0):
    return time * slope

# %%
time = np.arange(4 * 365 + 1)
series = trend(time,slope=0.1)
plotseries(time,series)

# %%
def seasonal_pattern(season_time):
    return np.where(season_time < 0.4,
                    np.cos(season_time * 2 * np.pi),
                    1 / np.exp(3 * season_time))

def seasonality(time,series,phase=0,amplitude=1):
    t = (time + period)

# %%
baseline = 10
amplitude = 40
seasonality(time, period=365, amplitude=amplitude).shape
# Out:
# (1461,)

# %%
((time+0)%365)/365
# Out:
# array([0.        , 0.00273973, 0.00547945, ..., 0.99452055, 0.99726027,
#        0.        ])
